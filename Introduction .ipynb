# %%
print("omda")
# Out:
# omda

# %%
st='omda'
i=19
print(st)
print(i)
# Out:
# omda
# 19

# %%
st
i
# Out:
# 19

# %%
my_num=22
if my_num>22:
    print("greater than 22")
elif my_num<22:
    print("smaler than 22")
else:
    print("equal 22")
# Out:
# equal 22

# %%
s_names = ['Alice', 'Bob', 'Carol', 'Dave']
s_names[1]
# Out:
# 'Bob'

# %%
s_names[3]
# Out:
# 'Dave'

# %%
s_names[-1]
# Out:
# 'Dave'

# %%
s_names[1:3]
# Out:
# ['Bob', 'Carol']

# %%
s_names[2:]
# Out:
# ['Carol', 'Dave']

# %%
s_names[:2]
# Out:
# ['Alice', 'Bob']

# %%
s_names.append('omda')

# %%
s_names
# Out:
# ['Alice', 'Bob', 'Carol', 'Dave', 'omda']

# %%
s_names.insert(2,'ali')
s_names
# Out:
# ['Alice', 'Bob', 'ali', 'Carol', 'Dave', 'omda']

# %%
del s_names[2]
s_names
# Out:
# ['Alice', 'Bob', 'Carol', 'Dave', 'omda']

# %%
for name in s_names:
    print('Hello' + name + ' . ')
# Out:
# HelloAlice .
# HelloBob .
# HelloCarol .
# HelloDave .
# Helloomda .

# %%
l_n = []
for name in s_names:
    if len(name) > 4:
        l_n.append(name)

l_n
# Out:
# ['Alice', 'Carol']

# %%
s_p = []
for name_0 in s_names:
    for name_1 in s_names:
        s_p.append((name_0,name_1))
s_p
# Out:
# [('Alice', 'Alice'),
#  ('Alice', 'Bob'),
#  ('Alice', 'Carol'),
#  ('Alice', 'Dave'),
#  ('Alice', 'omda'),
#  ('Bob', 'Alice'),
#  ('Bob', 'Bob'),
#  ('Bob', 'Carol'),
#  ('Bob', 'Dave'),
#  ('Bob', 'omda'),
#  ('Carol', 'Alice'),
#  ('Carol', 'Bob'),
#  ('Carol', 'Carol'),
#  ('Carol', 'Dave'),
#  ('Carol', 'omda'),
#  ('Dave', 'Alice'),
#  ('Dave', 'Bob'),
#  ('Dave', 'Carol'),
#  ('Dave', 'Dave'),
#  ('Dave', 'omda'),
#  ('omda', 'Alice'),
#  ('omda', 'Bob'),
#  ('omda', 'Carol'),
#  ('omda', 'Dave'),
#  ('omda', 'omda')]

# %%
s_p[1]
# Out:
# ('Alice', 'Bob')

# %%
s_g = ('omda', 'english', 'A-')
s_g
# Out:
# ('omda', 'english', 'A-')

# %%
s_g.append("assuit")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MICROS~1\AppData\Local\Temp/ipykernel_11248/318095894.py in <module>
# ----> 1 s_g.append("assuit")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
s_g = ('omda', 'english', 'A-')
name,lang,gba=s_g
print(name)
print(lang)
print(gba)
# Out:
# omda
# english
# A-

# %%
s_g = [
    ('omda', 'Spanish', 'A'),
    ('ali', 'French', 'C'),
    ('moh', 'Italian', 'B+'),
    ('fathy', 'Italian', 'A-'),
]
for name, su, g in s_g:
    if g.startswith('A'):
        print('Congratulations', name,
              'on getting an', g,
              'in', su)
# Out:
# Congratulations omda on getting an A in Spanish
# Congratulations fathy on getting an A- in Italian

# %%
f_l = {
    'omda': 'Spanish',
    'ali': 'French',
    'saad': 'Italian',
    'fathy': 'Italian',
}
f_l['omda']
# Out:
# 'Spanish'

# %%
'ali' in f_l
# Out:
# True

# %%
'aa' in f_l
# Out:
# False

# %%
f_l["fady"]='dss'
f_l
# Out:
# {'omda': 'Spanish',
#  'ali': 'French',
#  'saad': 'Italian',
#  'fathy': 'Italian',
#  'fady': 'dss'}

# %%
for k in f_l:
    v = f_l[k]
    print(k, 'is taking', v)
# Out:
# omda is taking Spanish
# ali is taking French
# saad is taking Italian
# fathy is taking Italian
# fady is taking dss

# %%
s_g = [
    ('ali', 'Spanish', 'A'),
    ('omda', 'French', 'C'),
    ('saad', 'Italian', 'B+'),
    ('fathy', 'Italian', 'A-'),
]
s_g[1]
# Out:
# ('omda', 'French', 'C')

# %%
s_g[1][2]
# Out:
# 'C'
